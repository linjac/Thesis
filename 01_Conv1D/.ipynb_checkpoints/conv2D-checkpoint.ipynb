# %% [markdown]
# # Conv1D

# %%
skip_training = False  # Set this flag to True before validation and submission

# %%
# During evaluation, this cell sets skip_training to True

import tools, warnings
warnings.showwarning = tools.customwarn

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# When running on your own computer, you can specify the data directory by:
# data_dir = tools.select_data_dir('/your/local/data/directory')
data_dir = tools.select_data_dir()
# Out:
# The data directory is ../data

# %%
# Select device which you are going to use for training
device = torch.device("cuda:0")
# device = torch.device("cpu")

# %%
if skip_training:
    # The models are always evaluated on CPU
    device = torch.device("cpu")

# %% [markdown]
# ## Data

# %%
from data import MotusDataset_best_of

cutoff = 0.05 #seconds of IR head
num_tail_samples = int(0.95*48000) # number of samples of IR tail

trainset = MotusDataset_best_of(root=data_dir, train=True, cutoff=cutoff, num_tail_samples=num_tail_samples, resample=None)
trainloader = torch.utils.data.DataLoader(dataset=trainset)
# trainloader = torch.utils.data.DataLoader(dataset=trainset, batch_size=1, collate_fn=collate, shuffle=True)

testset = MotusDataset_best_of(root=data_dir, train=False, cutoff=cutoff, num_tail_samples=num_tail_samples, resample=None)
testloader = torch.utils.data.DataLoader(dataset=testset)
# Out:
# C:\Users\jacki\anaconda3\envs\Thesis\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")
# ../data\Motus/best_of/sh_rirs
# ../data\Motus/best_of/sh_rirs

# %% [markdown]
# Let's visualize the data with some plots, and audio play the head and tail

# %%
sample_head, sample_tail = trainset[np.random.choice(len(trainset))]

fs = trainset.sample_rate
time1 = np.linspace(0,sample_head.shape[-1]/fs, sample_head.shape[-1])
time2 = np.linspace(time1[-1], sample_tail.shape[-1]/fs+time1[-1], sample_tail.shape[-1])

print(f'{time1.shape}, {sample_head.shape}')
print(f'{time2.shape}, {sample_tail.shape}')
#Plot the data 
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 100

fig, ax = plt.subplots(1)
ax.plot(time1, torch.flatten(sample_head), time2, torch.flatten(sample_tail), linewidth=1)
# ax.plot(time_scale, tgt_sample)
ax.legend(['IR - Head', 'IR - Tail'])
# plt.xlim([0.1, 0.25])
# plt.savefig('test_matplotlib.png', bbox_inches="tight")
plt.show()
# Out:
# (2400,), torch.Size([1, 2400])
# (45600,), torch.Size([1, 45600])

# %%
# Out:
# 5

# %%
from IPython.display import Audio, display

Audio(sample_head, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(sample_tail, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Architecture
#
# Lightweight model: fully connected layers=6, hidden size=32
#
# Architecture here:
# - Conv1D (out_chanels=32, kernel_size=4, stride=4) + Leaky ReLU
# - Conv1D (out_chanels=32, kernel_size=2, stride=2) + Leaky ReLU
#
# - Conv1D (out_chanels=128, kernel_size=2, stride=2) + Leaky ReLU
# - Conv1D (out_chanels=128, kernel_size=2, stri
# de=2) + Leaky ReLU
# - Conv1D (out_chanels=128, kernel_size=2, stride=2) + Leaky ReLU
#
# - Conv1D (out_chanels=out_channels, kernel_size=2, stride=2) + Leaky ReLU
# - linear layer (hidden size, hidden size) + Leaky ReLU
# - linear layer (hidden size, 1)

# %%
class IRCNN(nn.Module):
    def __init__(self, in_channels, out_channels, out_dim, negative_slope=0.01):
        super(IRCNN,self).__init__()
        
        self.conv = nn.Sequential(
            nn.Conv1d(in_channels, 32, 4, stride=4),
            nn.Conv1d(32, 32, 2, stride=2),
            nn.Conv1d(32, 128, 8, stride=8),
            nn.Conv1d(128, 128, 2, stride=2),
            nn.Conv1d(128, 512, 2, stride=2),
            nn.Conv1d(512, 512, 4, stride=4),
            nn.Conv1d(512, 1024, 2, stride=2),
            nn.Conv1d(1024, 1024, 1, stride=1),
            nn.Flatten(),
        )
        self.fcn1 = nn.LazyLinear(512)
        self.fcn2 = nn.Linear(512, out_dim)
        
    def forward(self, x):
        """
        Args:
            x of shape (batch_size*IR_len, input_mapped_dim = 4*2*10 = 80): 
            Tensor with transformed input position vectors.
        Returns:
            out of shape (batch_size, 1): value for time step t            
        """
        out = self.conv(x)
#         print(out.shape)
        out = self.fcn1(out)
#         out= self.nl1(out)
        out = self.fcn2(out)
#         out = self.nl2(out)
#         out = self.fcn3(out)
#         print(out.shape)
        
        return out

# %%
def test_IRCNN_shapes():
    x = torch.randn(2, 2, 2400)
    channels = x.shape[1]
    out_dim = 64
    model = IRCNN(channels, channels, out_dim)
    out = model(x)

test_IRCNN_shapes()

# %% [markdown]
# ### Training
# Initialize the IR-CNN model, then train.

# %%
channels = sample_head.shape[0]
out_dim = sample_tail.shape[-1]
cnn_model = IRCNN(channels, channels, out_dim).to(device)
print(cnn_model)
# Out:
# IRCNN(
#   (conv): Sequential(
#     (0): Conv1d(1, 32, kernel_size=(4,), stride=(4,))
#     (1): Conv1d(32, 32, kernel_size=(2,), stride=(2,))
#     (2): Conv1d(32, 128, kernel_size=(8,), stride=(8,))
#     (3): Conv1d(128, 128, kernel_size=(2,), stride=(2,))
#     (4): Conv1d(128, 512, kernel_size=(2,), stride=(2,))
#     (5): Conv1d(512, 512, kernel_size=(4,), stride=(4,))
#     (6): Conv1d(512, 1024, kernel_size=(2,), stride=(2,))
#     (7): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#     (8): Flatten(start_dim=1, end_dim=-1)
#   )
#   (fcn1): LazyLinear(in_features=0, out_features=512, bias=True)
#   (fcn2): Linear(in_features=512, out_features=45600, bias=True)
# )

# %%
###### For plotting every 10 epochs ######
time1 = np.linspace(0,sample_head.shape[-1]/fs, sample_head.shape[-1])
time2 = np.linspace(time1[-1], sample_tail.shape[-1]/fs+time1[-1], sample_tail.shape[-1])

###### Training #######
if not skip_training:
    EPOCHS = 1000
    optimizer = torch.optim.Adam(cnn_model.parameters(), lr=0.0001)
    criterion = nn.L1Loss()
    loss_over_time = []

    for epoch in range(EPOCHS):
        cnn_model.train()
        total_loss = 0
        for x, y in trainloader:
            x = x.to(device).float()
            y = y.to(device).float()
            out = cnn_model(x)
            
            # Zero gradient of optimizer:
            optimizer.zero_grad()
            loss = criterion(out, y.view(y.shape[0], -1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        loss_over_time.append(total_loss/len(trainloader))
        if epoch%10 == 9:
            print(f"Epoch {epoch+1}. Loss: {total_loss/len(trainloader)}")
        if epoch == 99 or epoch%500==499:
            with torch.no_grad():
                cnn_model.eval()
                x, y = trainset[0]
                x = x[None,:,:].to(device).float()
                y = y[None,:,:].to(device).float()
                y_pred = cnn_model(x)

                #Plot the data 
                fig, ax = plt.subplots(1)
                ax.plot(time2, torch.flatten(y.cpu()), time2, torch.flatten(y_pred.cpu()), ':')
                ax.set_title(f'Prediction for Epoch {epoch+1}')
                ax.legend(['GT - tail','Predicted - tail'])
                filename = "1s_cnn01_L1_e" + str(epoch+1).zfill(4) + "pred.png"
                plt.savefig(filename, bbox_inches="tight")

fig, ax = plt.subplots(1)
ax.plot(loss_over_time[5:])
ax.set_title(f'Training loss over {EPOCHS} Epochs')
plt.savefig("1s_cnn01_L1_training_loss.png", bbox_inches="tight")
plt.show()
# Out:
# Epoch 10. Loss: 0.001590568780604946
# Epoch 20. Loss: 0.0015965967659691447
# Epoch 30. Loss: 0.0015413565438632901
# Epoch 40. Loss: 0.0015151796672542236
# Epoch 50. Loss: 0.0015174722740132558
# Epoch 60. Loss: 0.0014874892352197907
# Epoch 70. Loss: 0.0014656279021628986
# Epoch 80. Loss: 0.001459738757387784
# Epoch 90. Loss: 0.0015288142083016666
# Epoch 100. Loss: 0.0015242756283106772
# Epoch 110. Loss: 0.0016700862049076118
# Epoch 120. Loss: 0.0017156665409473997
# Epoch 130. Loss: 0.001669408306234369
# Epoch 140. Loss: 0.0018186291961587574
# Epoch 150. Loss: 0.0015078347059898078
# Epoch 160. Loss: 0.001751360606010023
# Epoch 170. Loss: 0.0015533790176146124
# Epoch 180. Loss: 0.0014686942419135257
# Epoch 190. Loss: 0.0014022678093935706
# Epoch 200. Loss: 0.0014557709310841012
# Epoch 210. Loss: 0.0013507132871860737
# Epoch 220. Loss: 0.0013831667602062225
# Epoch 230. Loss: 0.0014091172243321413
# Epoch 240. Loss: 0.0013764746346216846
# Epoch 250. Loss: 0.0013204092637782818
# Epoch 260. Loss: 0.0014347210158839037
# Epoch 270. Loss: 0.0013003347894961113
# Epoch 280. Loss: 0.001290525337313547
# Epoch 290. Loss: 0.001318565814902908
# Epoch 300. Loss: 0.001272002850830751
# Epoch 310. Loss: 0.0011105324772774782
# Epoch 320. Loss: 0.0010808506355571904
# Epoch 330. Loss: 0.0012454698781335825
# Epoch 340. Loss: 0.001163821425411458
# Epoch 350. Loss: 0.0010623081378932846
# Epoch 360. Loss: 0.0009982765401027312
# Epoch 370. Loss: 0.0010855187153394677
# Epoch 380. Loss: 0.0010211925898482533
# Epoch 390. Loss: 0.0010484332298418802
# Epoch 400. Loss: 0.0010588715606565146
# Epoch 410. Loss: 0.0009710325210012103
# Epoch 420. Loss: 0.0009219085178828161
# Epoch 430. Loss: 0.0010297837526243377
# Epoch 440. Loss: 0.0009804246150643418
# Epoch 450. Loss: 0.0009228663831508081
# Epoch 460. Loss: 0.0008411482956848646
# Epoch 470. Loss: 0.000864805322826693
# Epoch 480. Loss: 0.0008863724682382063
# Epoch 490. Loss: 0.0008582335400493129
# Epoch 500. Loss: 0.0010161988412667263
# Epoch 510. Loss: 0.0010016316541862722
# Epoch 520. Loss: 0.0008624924689923462
# Epoch 530. Loss: 0.0008183442773052344
# Epoch 540. Loss: 0.0007596080785764283
# Epoch 550. Loss: 0.0010155160531499668
# Epoch 560. Loss: 0.00069783976007449
# Epoch 570. Loss: 0.00072321000104574
# Epoch 580. Loss: 0.0007030544879135528
# Epoch 590. Loss: 0.0007397146913909206
# Epoch 600. Loss: 0.0007693881527398174
# Epoch 610. Loss: 0.0007172285634289054
# Epoch 620. Loss: 0.0006599998450838029
# Epoch 630. Loss: 0.0007827805759581296
# Epoch 640. Loss: 0.0006833407816501628
# Epoch 650. Loss: 0.0007616288800674834
# Epoch 660. Loss: 0.0006121387889020537
# Epoch 670. Loss: 0.000707430789541257
# Epoch 680. Loss: 0.0006385736250147028
# Epoch 690. Loss: 0.000766145871143396
# Epoch 700. Loss: 0.0006018599470783221
# Epoch 710. Loss: 0.0006730204913765192
# Epoch 720. Loss: 0.0008323943138269609
# Epoch 730. Loss: 0.0006803671039003683
# Epoch 740. Loss: 0.0005353320448193699
# Epoch 750. Loss: 0.0006321467900354611
# Epoch 760. Loss: 0.0006071870968873171
# Epoch 770. Loss: 0.0006223451836328758
# Epoch 780. Loss: 0.0005849449815669734
# Epoch 790. Loss: 0.0005618287127857146
# Epoch 800. Loss: 0.000559486782692961
# Epoch 810. Loss: 0.0005829069643943129
# Epoch 820. Loss: 0.0006042769757761178
# Epoch 830. Loss: 0.000611386025986193
# Epoch 840. Loss: 0.0006512780735073121
# Epoch 850. Loss: 0.0006731131962672072
# Epoch 860. Loss: 0.000659125486364294
# Epoch 870. Loss: 0.0005979982057684346
# Epoch 880. Loss: 0.0006254141917452216
# Epoch 890. Loss: 0.0005455339207975684
# Epoch 900. Loss: 0.0006549845688584211
# Epoch 910. Loss: 0.0005420946016736133
# Epoch 920. Loss: 0.0006847628193147676
# Epoch 930. Loss: 0.0005157377347227578
# Epoch 940. Loss: 0.0005998493303961464
# Epoch 950. Loss: 0.0005960446325939541
# Epoch 960. Loss: 0.0006457591922586097
# Epoch 970. Loss: 0.0005997654010762313
# Epoch 980. Loss: 0.0005736463338651351
# Epoch 990. Loss: 0.0006061316296262177
# Epoch 1000. Loss: 0.0005453326203247631

# %%
with torch.no_grad():
    cnn_model.eval()
    idx = 0
    x, y = testset[idx]
    x = x[None,:,:].to(device).float()
    y = y[None,:,:].to(device).float()
    y_pred = cnn_model(x)
    loss = criterion(y_pred,y)
    print(f"Test_loss: {loss.item()}")

    #Plot the data 
    fig, ax = plt.subplots(1)
    ax.plot(time2, torch.flatten(y.cpu()))
    ax.plot(time2, torch.flatten(y_pred.cpu()), ':')
    ax.set_title(f'Prediction for Epoch {epoch+1}')
    ax.legend(['GT - tail','Predicted - tail'])
#     plt.xlim([0.85,0.95])
    filename = "1s_cnn01_L1_e" + str(epoch+1).zfill(4) + "test"+ str(idx) + ".png"
    plt.savefig(filename, bbox_inches="tight")
# Out:
# Test_loss: 0.0012403030414134264

# %%
with torch.no_grad():
    cnn_model.eval()
    x, y = trainset[0]
    x = x[None,:,:].to(device).float()
    y = y[None,:,:].cpu().float()
    y_pred = cnn_model(x)
    pa_ref = 2e-5
    
    gt_energy = 10*torch.log10((torch.flatten(y)/pa_ref)**2)
    pred_energy = 10*torch.log10((torch.flatten(y_pred.cpu())/pa_ref)**2)
    fig, ax = plt.subplots(1)    
    ax.plot(time2, pred_energy, ':')
    ax.plot(time2, gt_energy)
    ax.legend(['Energy, db' ])
    plt.show()

# %%
if not skip_training:
    tools.save_model(cnn_model, '1s_cnn01_L1.pth', confirm=True)
# Out:
# Do you want to save the model (type yes to confirm)?  yes
# Model saved to 1s_cnn01_L1.pth.

# %%
y_pred_e1000 = y_pred.to(torch.device("cpu"))

# %%
x_e1000 = x.cpu()
y_e1000 = y.cpu()

# %%
Audio(torch.cat((x_e1000.view(-1),y_e1000.view(-1))), rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(torch.cat((x_e1000.view(-1),y_pred_e1000.view(-1))), rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Epoch 2000

# %%
x_e2000 = x.cpu()
y_e2000 = y.cpu()
y_pred_e2000 = y_pred.cpu()

# %%
Audio(torch.cat((x_e2000.view(-1),y_e2000.view(-1))), rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(torch.cat((x_e2000.view(-1),y_pred_e2000.view(-1))), rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Epoch 2000

# %%
x_e2585 = x.cpu()
y_e2585 = y.cpu()
y_pred_e2585 = y_pred.cpu()

# %%
Audio(torch.cat((x_e2585.view(-1),y_e2585.view(-1))), rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(torch.cat((x_e2585.view(-1),y_pred_e2585.view(-1))), rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Architecture - MLP

# %%
class IRMLP(nn.Module):
    def __init__(self, hidden_size, out_dim, negative_slope=0.00):
        super(IRMLP,self).__init__()
        
        self.fcn = nn.Sequential(
            nn.LazyLinear(hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, hidden_size),
            nn.LeakyReLU(negative_slope),
            nn.Linear(hidden_size, out_dim),
        )
    def forward(self, x):
        """
        Args:
            x of shape (batch_size*IR_len, input_mapped_dim = 4*2*10 = 80): 
            Tensor with transformed input position vectors.
        Returns:t
            out of shape (batch_size, 1): value for time step t            
        """
        out = self.fcn(x)
#         print(out.shape)
        
        return out

# %%
def test_IRMLP_shapes():
    x = torch.randn(2, 1, 2400)
    hidden_size = 128
    out_dim = 64
    model = IRMLP(hidden_size, out_dim)
    out = model(x)

test_IRMLP_shapes()

# %% [markdown]
# ### Training
# Initialize the IR-CNN model, then train.

# %%
hidden_size = 64
out_dim = sample_tail.shape[-1]
model = IRMLP(hidden_size, num_tail_samples).to(device)
print(model)
# Out:
# IRMLP(
#   (fcn): Sequential(
#     (0): LazyLinear(in_features=0, out_features=64, bias=True)
#     (1): LeakyReLU(negative_slope=0.0)
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): LeakyReLU(negative_slope=0.0)
#     (4): Linear(in_features=64, out_features=64, bias=True)
#     (5): LeakyReLU(negative_slope=0.0)
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): LeakyReLU(negative_slope=0.0)
#     (8): Linear(in_features=64, out_features=64, bias=True)
#     (9): LeakyReLU(negative_slope=0.0)
#     (10): Linear(in_features=64, out_features=64, bias=True)
#     (11): LeakyReLU(negative_slope=0.0)
#     (12): Linear(in_features=64, out_features=64, bias=True)
#     (13): LeakyReLU(negative_slope=0.0)
#     (14): Linear(in_features=64, out_features=64, bias=True)
#     (15): LeakyReLU(negative_slope=0.0)
#     (16): Linear(in_features=64, out_features=64, bias=True)
#   )
# )

# %%
###### For plotting every 10 epochs ######
time1 = np.linspace(0,sample_head.shape[-1]/fs, sample_head.shape[-1])
time2 = np.linspace(time1[-1], sample_tail.shape[-1]/fs+time1[-1], sample_tail.shape[-1])

###### Training #######
if not skip_training:
    EPOCHS = 500
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss(reduction='sum')
    
    loss_over_time_mlp = []

    for epoch in range(EPOCHS):
        model.train()
        total_loss = 0
        for x, y in trainloader:
            x = x.to(device).float()
            y = y.to(device).float()
            out = model(x)
            
            # Zero gradient of optimizer:
            optimizer.zero_grad()
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            
        loss_over_time_mlp.append(total_loss/len(trainloader))
        if epoch%10 == 9:
            print(f"Epoch {epoch+1}. Loss: {total_loss/len(trainloader)}")
        if epoch==99 or epoch==499:
            with torch.no_grad():
                model.eval()
                x, y = trainset[np.random.choice(len(trainset))]
                x = x[None,:,:].to(device).float()
                y = y[None,:,:].to(device).float()
                y_pred = model(x)

                #Plot the data 
                fig, ax = plt.subplots(1)
                ax.plot(time2, torch.flatten(y.cpu()), time2, torch.flatten(out.cpu()), ':')
                ax.legend(['GT - tail','Predicted - tail'])

                ax.set_title(f'Prediction for Epoch {epoch+1}')
                filename = "mlp_e" + str(epoch).zfill(4) + "pred.png"
                plt.savefig(filename, bbox_inches="tight")
fig, ax = plt.subplots(1)  
ax.plot(loss_over_time_mlp)
ax.set_title(f'Training loss over {EPOCHS} Epochs')
plt.savefig("mlp_training_loss.png", bbox_inches="tight")
plt.show()
# Out:
# Epoch 10. Loss: 0.019870741292834282
# Epoch 20. Loss: 0.012821635114960372
# Epoch 30. Loss: 0.01145770742247502
# Epoch 40. Loss: 0.007888557098340243
# Epoch 50. Loss: 0.00586640492110746
# Epoch 60. Loss: 0.004938385381440942
# Epoch 70. Loss: 0.006926361990432876
# Epoch 80. Loss: 0.0038911989274007888
# Epoch 90. Loss: 0.002597368657006882
# Epoch 100. Loss: 0.0021194573637330905
# Epoch 110. Loss: 0.00683150455976526
# Epoch 120. Loss: 0.0017413021159882192
# Epoch 130. Loss: 0.0012382838685880415
# Epoch 140. Loss: 0.0013431854580024567
# Epoch 150. Loss: 0.0020540768576514288
# Epoch 160. Loss: 0.0015905498742843822
# Epoch 170. Loss: 0.004756150699298208
# Epoch 180. Loss: 0.001229918111372778
# Epoch 190. Loss: 0.000655137801610787
# Epoch 200. Loss: 0.0011985515811829828
# Epoch 210. Loss: 0.0017681042227195576
# Epoch 220. Loss: 0.0007614740849627802
# Epoch 230. Loss: 0.0009200441436405526
# Epoch 240. Loss: 0.0023339106167744226
# Epoch 250. Loss: 0.002338324874775329
# Epoch 260. Loss: 0.00020935853444825625
# Epoch 270. Loss: 0.000259271718277887
# Epoch 280. Loss: 0.00033024783836784383
# Epoch 290. Loss: 0.002016982183098056
# Epoch 300. Loss: 0.0022288307858010135
# Epoch 310. Loss: 0.0006044320737904248
# Epoch 320. Loss: 0.0007108965413256859
# Epoch 330. Loss: 0.0006659453659570621
# Epoch 340. Loss: 0.0008820213976529582
# Epoch 350. Loss: 0.006196794648227903
# Epoch 360. Loss: 0.0007033655680667531
# Epoch 370. Loss: 0.00011793650340526558
# Epoch 380. Loss: 6.662096977076241e-05
# Epoch 390. Loss: 0.00010770336575660622
# Epoch 400. Loss: 0.0004346396168936432
# Epoch 410. Loss: 0.008148609684819045
# Epoch 420. Loss: 0.0016376753119402565
# Epoch 430. Loss: 0.0006717078534469086
# Epoch 440. Loss: 0.0002286415556227439
# Epoch 450. Loss: 0.0002430353138151986
# Epoch 460. Loss: 0.0006345124093058985
# Epoch 470. Loss: 0.0010726992004492786
# Epoch 480. Loss: 0.0010456693089508917
# Epoch 490. Loss: 0.0014211369671102148
# Epoch 500. Loss: 0.0003489842019916978

# %%
fig, ax = plt.subplots(1)  
ax.plot(loss_over_time_mlp)
ax.set_title(f'Training loss over {EPOCHS} Epochs')
plt.savefig("mlp_training_loss.png", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(1)  
ax.plot(loss_over_time)
ax.plot(loss_over_time_mlp)
ax.legend(['Conv1d', 'Linear'])
ax.set_title(f'Training loss over {EPOCHS} Epochs')
ax.set_yscale('log')
plt.savefig("cnn_mlp_training_loss.png", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(1)  
ax.plot(loss_over_time)
ax.plot(loss_over_time01)
ax.plot(loss_over_time02)
ax.plot(loss_over_time_mlp)
ax.legend(['Conv1d','Conv1d-01', 'Conv1d-02','Linear'])
ax.set_yscale('log')
ax.set_title(f'Training loss over {EPOCHS} Epochs')
plt.savefig("cnn_cnn01_cnn02_mlp_training_loss.png", bbox_inches="tight")
plt.show()
