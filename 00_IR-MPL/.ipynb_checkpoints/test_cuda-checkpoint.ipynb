# %%
import torch

# %%
x = torch.rand(5,3)
print(x)
# Out:
# tensor([[0.6882, 0.4716, 0.3984],
#         [0.3085, 0.5790, 0.6169],
#         [0.3556, 0.6532, 0.1846],
#         [0.3399, 0.2780, 0.4378],
#         [0.2626, 0.5786, 0.5691]])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from data import resample_waveform, get_sine_sweep, plot_sweep

sample_rate = 48000
waveform = get_sine_sweep(sample_rate)

plot_sweep(waveform, sample_rate, title="Original Waveform")
Audio(waveform.numpy()[0], rate=sample_rate)
# Out:
# C:\Users\jacki\anaconda3\envs\Thesis\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 waveform = get_sine_sweep(sample_rate)
#       6 plot_sweep(waveform, sample_rate, title="Original Waveform")
# ----> 7 Audio(waveform.numpy()[0], rate=sample_rate)
#
# NameError: name 'Audio' is not defined

# %%
sample_rate = 48000
waveform = get_sine_sweep(sample_rate)
resample_rate = 16000

resampled_sweep = resample_waveform(waveform, sample_rate, resample_rate)

# %%
print(resampled_sweep.shape)
many = waveform.repeat(3,1)
print(many.shape)
resample_sweeps = resample_waveform(many, sample_rate, resample_rate)
# Out:
# torch.Size([1, 16000])
# torch.Size([3, 48000])

# %%
resample_sweeps.shape
# Out:
# torch.Size([3, 16000])

# %%
plot_sweep(, sample_rate, title="Original Waveform")
